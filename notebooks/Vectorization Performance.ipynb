# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
perf = np.asarray([
    144.9387891292572,
    102.52791285514832,
    76.90360188484192,
    62.09321880340576,
    54.29495978355408,
    52.900399923324585])
size = np.asarray([4, 8, 16, 32, 64, 128])

# %%
plt.plot(size, perf)
plt.title('Vectorization Performance')
plt.xlabel('Batch Size')
plt.ylabel('Seconds')
plt.tight_layout()
