# %%
# %matplotlib inline

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = tf.random.normal(shape=[100, 100], mean=0.0, stddev=1.0)
X_norm = X * tf.sqrt(2 / 100)
plt.figure(figsize=(8, 8))
plt.imshow(X_norm, interpolation=None)
plt.colorbar()

# %%
X_norm = X * tf.sqrt(2 / tf.reduce_sum(tf.square(X), axis=0, keepdims=True))
plt.figure(figsize=(8, 8))
plt.imshow(X_norm, interpolation=None)
plt.colorbar()
